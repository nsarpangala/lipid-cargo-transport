# %%
#combines the runlength, average number of motors for 2mM and 4uM simulations with data from 100um runs.
import pandas as pd
import os

filename="average_motor_runlength"
high_low=pd.read_csv('summary_high_low_atp.csv',index_col=0)
mid_atp=pd.read_csv('summary_mid_atp.csv',index_col=0)
mid_atp = mid_atp.drop(columns=["measured_velocity","vel_error"])
frames = [high_low, mid_atp]
result = pd.concat(frames,axis=0)
frames = [high_low, mid_atp]
result = pd.concat(frames,axis=0,ignore_index=True)
data_top = result.head()  
result=result.rename(columns={"ATP": "[ATP] (M)", "Inp. velocity (ums-1)": "v0 (m/s)","mean_run": "mean_run (m)",
                             "runerror":"runerror (m)","liftimeerror":"lifetimeerror (s)"})
result.to_csv(filename+'.csv', index = False)
# Out:
#               set xlabel  D (um2s-1)       ATP  Inp. velocity (ums-1)  \
# 0  N=4 High [ATP]     D0        0.00  0.002000           8.000000e-07
# 1  N=4 High [ATP]     D2        0.01  0.002000           8.000000e-07
# 2  N=4 High [ATP]     D4        1.00  0.002000           8.000000e-07
# 3   N=4 Low [ATP]     D0        0.00  0.000005           8.000000e-08
# 4   N=4 Low [ATP]     D2        0.01  0.000005           8.000000e-08
#
#    av_bound  bound_error      mean_run      runerror  mean_lifetime (s)  \
# 0  1.190000     0.003651  8.680000e-07  6.640000e-08           1.093890
# 1  1.233413     0.003681  9.670000e-07  8.330000e-08           1.236792
# 2  1.334360     0.004572  9.980000e-07  7.410000e-08           1.264212
# 3  1.647882     0.000957  1.550000e-06  1.750000e-07          19.373620
# 4  2.259076     0.000914  3.940000e-06  3.780000e-07          49.404149
#
#    liftimeerror
# 0      0.081801
# 1      0.104391
# 2      0.093830
# 3      2.200076
# 4      4.778046
